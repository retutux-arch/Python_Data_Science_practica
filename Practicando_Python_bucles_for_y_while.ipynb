# %% [markdown]
# <a href="https://colab.research.google.com/github/retutux-arch/Python_Data_Science_practica/blob/main/Practicando_Python_bucles_for_y_while.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Comprendiendo lazos
#
# Ana está desarrollando un programa que necesita procesar una lista de 5 nombres de clientes para generar informes mensuales. Para ello, necesita escribir un programa que recorra la lista de nombres y muestre cada cliente.

# %%
clientes = ["Juan", "Maria", "Carlos", "Ana", "Beatriz"]

# %% [markdown]
# Ayuda a Ana a decidir entre usar un lazo for o while. Escribe el programa usando el lazo que creas más adecuado para esta tarea y explica por qué elegiste ese lazo.

# %%
# Utilizar for es lo mas adecuado si se conoce la cantidad de objetos en la lista.

for cliente in clientes:
    print(cliente)

# %% [markdown]
# # ¿Qué es un bucle infinito?
#
# André está probando una nueva función en el backend de Buscante que procesa datos en un bucle. Durante las pruebas, se dio cuenta de que el sistema dejó de responder y sospecha que el problema está en un bucle infinito.

# %% [markdown]
# ```
# contador = 0
#
# while contador < 10:
#     print("Procesando datos...")
# ```

# %% [markdown]
# ¿Cuál es el problema del código de André y cómo resolverlo?

# %%
contador = 0

while contador < 10:
    print(f"Procesando datos...{contador}")
    contador += 1 # el codigo no poseia un codigo para terminar el bucle.

# %% [markdown]
# #¿Cuántas veces se mostrará el mensaje?
#
# Marcos está desarrollando un programa para mostrar un mensaje de bienvenida repetidamente en la consola, como parte de una campaña de marketing de su plataforma llamada Buscante. Quiere asegurarse de que el mensaje se muestre 5 veces.
#
# Ayuda a Marcos a escribir un programa que muestre el mensaje: "¡Bienvenido a Buscante!" el número exacto de veces que necesita.
#
# Salida esperada:
#
# * Bienvenido a Buscante!
# * Bienvenido a Buscante!
# * Bienvenido a Buscante!
# * Bienvenido a Buscante!
# * Bienvenido a Buscante!

# %%
palabra = "¡Bienvenido a Buscante!"

for i in range(5):
  print(palabra)

# %% [markdown]
# #$Calculando la suma de números
#
# Estás recibiendo una lista de valores que representan los productos de tu tienda virtual y te gustaría calcular la suma total de esos productos para entender el desempeño financiero semanal.
#
# valores = [10, 20, 30, 40, 50]
# Copia el código
# Crea un programa para implementar la suma.
#
# Salida esperada:
#
# La suma totaol de los ingresos es : 150

# %%
valores = [10, 20, 30, 40, 50]

suma = 0

for valor in valores:
  suma += valor
print(f'La suma de los ingresos es : {suma}')

# %%
#opcional

valores = [10, 20, 30, 40, 50]

suma = sum(valores)
print(f'La suma de los ingresos es : {suma}')

# %% [markdown]
# #Organizando tu portafolio
#
# Ana está desarrollando su portafolio para exhibir los proyectos de Python que ha completado. Ella organizó una lista con el nombre de cada proyecto, pero se dio cuenta de que algunos elementos pueden estar ausentes, apareciendo como None:
#
# proyectos = ["sitio web", "juego", "análisis de datos", None, "aplicativo móvil"]
#
# Crea un programa que ayude a Ana a recorrer la lista de proyectos y muestre los nombres de los proyectos válidos. Si encuentra un elemento None, el programa debe mostrar el mensaje: "Proyecto ausente".
#
# **Salida esperada:**
#
# * sitio web
# * juego
# * análisis de datos
# * Proyecto ausente
# * aplicativo móvil

# %%
proyectos = ["sitio web", "juego", "análisis de datos", None, "aplicativo móvil"]

for proyecto in proyectos :
  if proyecto is not None: #si no es NONE imrpime proyecto
    print(proyecto)
  else:
    print("Proyecto ausente")# si es NONE, lo reemplaza por "Proyecto ausente"

# %%
proyectos = ["sitio web", "juego", "análisis de datos", None,0, "",[], "aplicativo móvil"]

for proyecto in proyectos :
  if proyecto:
    print(proyecto)# Evalua los datos como booleano, None es falso
  else:
    print("Proyecto ausente")# se ejecuta else impriemiento "Proyecto ausente" en lugar de los falsey

# %%
# codigo instructor

proyectos = ["sitio web", "juego", "análisis de datos", None, "aplicativo móvil"]

for proyecto in proyectos:
    if proyecto is None:
        print("Proyecto ausente")# si es None imprime "Proyecto ausente" en el lugar de None
    else:
        print(proyecto)# imprime el resto de la lista con el valor reemplazado.

# %% [markdown]
# # Entendiendo el uso del break
#
#
# José está desarrollando una funcionalidad en el sistema de Buscante para interrumpir la búsqueda tan pronto como se encuentre un libro específico. La lista de libros ya registrados en el sistema es la siguiente:
#
# `libros = ["1984", "Cien años de soledad", "El Principito", "El Hobbit", "Orgullo y Prejuicio"]`
#
# Ayuda a José a crear un programa que recorra la lista y muestre el mensaje "Libro encontrado: <nombre del libro>" tan pronto como se encuentre el libro "El Hobbit". Después de encontrar el libro, el programa debe detener inmediatamente la búsqueda, sin verificar los libros restantes.
#
# Salida esperada:
#
#    libro encontrado : El Hobbit

# %%
libros = ["1984", "Cien años de soledad", "El Principito", "El Hobbit", "Orgullo y Prejuicio"]

for libro in libros:
  if libro == "El Hobbit":
    print(f'Libro encontrado: {libro}')
    break

print("Búsqueda terminada.")

# %%
# codigo verificacion
''' Sin la línea break del código, el bucle for seguirá iterando a través
 de todos los elementos de la lista libros, incluso después de haber encontrado y
 reportado que "El Hobbit" fue encontrado.  '''

libros = ["1984", "Cien años de soledad", "El Principito", "El Hobbit", "Orgullo y Prejuicio"]

print("Iniciando búsqueda...")
for libro in libros:
  print(f"Verificando: {libro}") # Añadimos este print para ver cada iteración
  if libro == "El Hobbit":
    print(f'Libro encontrado: {libro}')
    break # Aquí, el break detendrá el bucle inmediatamente

print("Búsqueda terminada.") # Este print nos dirá si el bucle completó o se detuvo

# %%
#codigo instructor

libros = ["1984", "Cien años de soledad", "El Principito", "El Hobbit", "Orgullo y Prejuicio"]

for libro in libros:
    if libro == "El Hobbit":
        print(f"Libro encontrado: {libro}")
        break

# %% [markdown]
# # Control de inventario
#
#
# Estás desarrollando un sistema de control de inventario para Buscante. Uno de los requisitos es verificar la cantidad de ejemplares de un libro en inventario y continuar vendiendo hasta que el inventario se agote. Siempre que se realiza una venta, el sistema debe informar al usuario y actualizar la cantidad disponible.
#
# Crea un programa que simule las ventas de un libro con el inventario inicial de 5 ejemplares. El programa debe mostrar el mensaje "¡Venta realizada! Inventario restante: <cantidad>" con cada venta y, al final, mostrar el mensaje "Inventario agotado".
#
# **Salida esperada:**
#
#   "¡Venta realizada! Inventario restante: 5
#
#   "¡Venta realizada! Inventario restante: 4
#
#   "¡Venta realizada! Inventario restante: 3
#
#   "¡Venta realizada! Inventario restante: 2
#
#   "¡Venta realizada! Inventario restante: 1
#
#   Intenraio agotado

# %%
libros = ["1984", "Cien años de soledad", "El Principito", "El Hobbit", "Orgullo y Prejuicio",]

contador_libros = len(libros)
total_inventario = contador_libros

print(f'¡Venta realizada! Inventario restante: {len(libros)}')


for i in range(total_inventario):
  total_inventario -= 1
  if total_inventario > 0:
    print(f'¡Venta realizada! Inventario restante: {total_inventario}')


print("Inventario agotado")

# %%
libros = ["1984", "Cien años de soledad", "El Principito", "El Hobbit", "Orgullo y Prejuicio"]

print(f"Inventario inicial ({len(libros)} libros):", libros)

print("\nIniciando simulación de ventas (ingresa 'salir' para terminar):")

# Crear una lista de libros en minúsculas para facilitar la comparación
libros_lower = [libro.lower() for libro in libros]

while libros: # El bucle continúa mientras la lista de libros no esté vacía
  print(f"\nInventario actual ({len(libros)} libros):", libros)
  libro_a_vender = input("Ingresa el nombre del libro a vender: ").lower() # Convertir la entrada del usuario a minúsculas

  if libro_a_vender == 'salir':
    print("Simulación de ventas terminada por el usuario.")
    break # Salir del bucle si el usuario ingresa 'salir'

  if libro_a_vender in libros_lower: # Comparar con la lista de libros en minúsculas
    # Encontrar el nombre original del libro para eliminarlo de la lista original
    index_to_remove = libros_lower.index(libro_a_vender)
    libro_vendido = libros.pop(index_to_remove)
    libros_lower.pop(index_to_remove) # Eliminar también de la lista en minúsculas

    print(f'¡Venta realizada de "{libro_vendido}"!')
    print(f"Inventario restante: {len(libros)} libros") # Ya estaba len() aquí
  else:
    print(f'"{libro_a_vender}" no se encuentra en el inventario. Intenta de nuevo.')

if not libros: # Verificar si el bucle terminó porque el inventario se agotó
  print("\nInventario agotado")

# %%
# Sistema de inventario con diccionarios

# Diccionario para mapear códigos de libro a nombres
libros_por_codigo = {
    "L001": "1984",
    "L002": "Cien años de soledad",
    "L003": "El Principito",
    "L004": "El Hobbit",
    "L005": "Orgullo y Prejuicio"
}

# Diccionario para mapear códigos de libro a cantidades en inventario
inventario_por_codigo = {
    "L001": 3,
    "L002": 5,
    "L003": 2,
    "L004": 4,
    "L005": 1
}

print("Inventario inicial:")
for codigo, nombre in libros_por_codigo.items():
    print(f"Código: {codigo}, Libro: {nombre}, Cantidad: {inventario_por_codigo[codigo]}")

print("\nSimulación de ventas (ingresa el código del libro o 'salir'):")

while True:
    codigo_a_vender = input("Ingresa el código del libro a vender: ").upper() # Convertir a mayúsculas para coincidir con las claves

    if codigo_a_vender == 'SALIR':
        print("Simulación de ventas terminada.")
        break

    if codigo_a_vender in inventario_por_codigo:
        if inventario_por_codigo[codigo_a_vender] > 0:
            inventario_por_codigo[codigo_a_vender] -= 1
            nombre_libro = libros_por_codigo[codigo_a_vender]
            print(f"¡Venta realizada de '{nombre_libro}' (Código: {codigo_a_vender})!")
            print(f"Inventario restante para '{nombre_libro}': {inventario_por_codigo[codigo_a_vender]}")

            # Opcional: verificar si el inventario total se agotó para todos los libros
            total_inventario_restante = sum(inventario_por_codigo.values())
            if total_inventario_restante == 0:
                print("\n¡Inventario total agotado!")
                break

        else:
            nombre_libro = libros_por_codigo[codigo_a_vender]
            print(f"¡'{nombre_libro}' (Código: {codigo_a_vender}) está agotado!")
    else:
        print(f"Código '{codigo_a_vender}' no válido. Intenta de nuevo.")

print("\nInventario final:")
for codigo, nombre in libros_por_codigo.items():
    # Corregido: Usar f-string para formatear la salida correctamente
    print(f"Código: {codigo}, Libro: {nombre}, Cantidad: {inventario_por_codigo.get(codigo, 0)}") # Usar .get por si un código fue eliminado o no existía inicialmente

# %%
#codigo instructor

inventario = 5

while inventario > 0:
    print(f"¡Venta realizada! Inventario restante: {inventario}")
    inventario -= 1

print("Inventario agotado")

# %% [markdown]
# # Cuenta Regresiva
#
# Aline está implementando una funcionalidad que muestra mensajes personalizados para los clientes durante una promoción especial de su nueva librería. El sistema debe mostrar un mensaje de cuenta regresiva personalizado para cada número de 10 a 1, y al final mostrar el mensaje: "¡Aprovecha la promoción ahora!".
#
# Crea un programa que utilice un bucle for para mostrar los siguientes mensajes:
#
# Para números pares, muestra: "Faltan solo <número> segundos - ¡No pierdas esta oportunidad!".
# Para números impares, muestra: "La cuenta continúa: <número> segundos restantes.".
# Al final de la cuenta, muestra el mensaje: "¡Aprovecha la promoción ahora!".

# %%
contador = 10

while contador >= 1:
  if contador % 2 == 0:
    print(f"Faltan solo {contador} segundos - ¡No pierdas esta oportunidad!")
  else :
    print(f"La cuenta continúa: {contador} segundos restantes.")
  contador -= 1

print( "¡Aprovecha la promoción ahora!")

# %%
#Codigo instructor.

for segundos in range(10, 0, -1):
    if segundos % 2 == 0:
        print(f"Faltan solo {segundos} segundos - ¡No pierdas esta oportunidad!")
    else:
        print(f"La cuenta continúa: {segundos} segundos restantes.")

print("¡Aprovecha la promoción ahora!")

# %% [markdown]
# # Utilidad del continue en bucles
#
#
# Ana está implementando un sistema de filtrado de libros en Buscante. La funcionalidad debe recorrer una lista de libros y mostrar el nombre de cada libro disponible en stock. Sin embargo, si el libro está agotado, debe ser ignorado durante la iteración.
#
#
#
# ```
#  libros = [
#     {"nombre": "1984", "stock": 5},
#     {"nombre": "Dom Casmurro", "stock": 0},
#     {"nombre": "El Principito", "stock": 3},
#     {"nombre": "El Hobbit", "stock": 0},
#     {"nombre": "Orgullo y Prejuicio", "stock": 2}
# ]
# ```
#
# Crea un programa que ayude a Ana a mostrar solamente los libros que tienen stock disponible, en el formato: "Libro disponible: <nombre del libro>".

# %%
libros = [
    {"nombre": "1984", "stock": 5},
    {"nombre": "Dom Casmurro", "stock": 0},
    {"nombre": "El Principito", "stock": 3},
    {"nombre": "El Hobbit", "stock": 0},
    {"nombre": "Orgullo y Prejuicio", "stock": 2}
]

for libro in libros:
  if libro["stock"] == 0:
    continue
  else:
    print(f"Libro disponible: {libro['nombre']}")

# %%
# codigo instructor.

libros = [
    {"nombre": "1984", "stock": 5},
    {"nombre": "Dom Casmurro", "stock": 0},
    {"nombre": "El Principito", "stock": 3},
    {"nombre": "El Hobbit", "stock": 0},
    {"nombre": "Orgullo y Prejuicio", "stock": 2}
]

for libro in libros:
    if libro["stock"] == 0:
        continue
    print(f"Libro disponible: {libro['nombre']}")

# %% [markdown]
# # Validación de entrada para inicio de sesión
#
#
# João está desarrollando un sistema de registro para un sitio de lectura. Necesita asegurarse de que los usuarios ingresen un nombre de usuario y una contraseña válidos. Las reglas son las siguientes:
#
# El nombre de usuario debe tener al menos 5 caracteres.
# La contraseña debe tener al menos 8 caracteres.
# João quiere que el sistema siga solicitando la información hasta que ambas condiciones se cumplan. Cuando el usuario ingresa datos válidos, el programa debe mostrar el mensaje: "¡Registro realizado con éxito!".
#
# Crea un programa que implemente esta lógica usando un bucle while.

# %%
''' Cumple con lo solicitado y si fallas la contraseña solo vuelve a pedir la contraseña, pero no es la logica
mas adecuada para aplicarlo.'''

usuario = input("Ingrese su nombre de usuario (minimo 5 caracteres): ")

while len(usuario) < 5:
  print("Nombre de usaurio debe tener al menos 5 caracteres")
  usuario = input("Ingrese su nombre de usuario (minimo 5 caracteres): ")
else:
    contraseña = input("Ingrese su contraseña (minimo 8 caracteres): ")
while len(contraseña) < 8:
        print("Contraseña debe tener al menos 8 caracteres")
        contraseña = input("Ingrese su contraseña (minimo 8 caracteres): ")
else:
    print("¡Registro realizado con éxito!")

# %%
''' Cumple, pero al fallar la contraseña vuelve a solicitar el nombre, el cual ya estaba validado.'''

while True:
    usuario = input("Ingrese su nombre de usuario (minimo 5 caracteres): ")
    if len(usuario) < 5:
        print("Nombre de usuario debe tener al menos 5 caracteres")
        continue

    contraseña = input("Ingrese su contraseña (minimo 8 caracteres): ")
    if len(contraseña) < 8:
        print("Contraseña debe tener al menos 8 caracteres")
        continue

    # Si llegamos aquí, tanto el usuario como la contraseña son válidos
    print("¡Registro realizado con éxito!")
    break # Salir del bucle cuando ambos son válidos

# %%
''' Cumple con lo solicitado y si fallas la contraseña solo vuelve a pedir la contraseña y utiliza
una logica mas adecuada, pero son necesarios 2 bluces.'''

# Validar nombre de usuario primero
while True:
    usuario = input("Ingrese su nombre de usuario (minimo 5 caracteres): ")
    if len(usuario) >= 5:
        break  # Salir de este bucle si el nombre de usuario es válido
    else:
        print("Nombre de usuario debe tener al menos 5 caracteres")

# Ahora, validar la contraseña solo si el nombre de usuario es válido
while True:
    contraseña = input("Ingrese su contraseña (minimo 8 caracteres): ")
    if len(contraseña) >= 8:
        break # Salir de este bucle si la contraseña es válida
    else:
        print("Contraseña debe tener al menos 8 caracteres")

# Si ambos bucles terminaron, significa que tanto el usuario como la contraseña son válidos
print("¡Registro realizado con éxito!")

# %%
''' Cumple con lo solicitado y si fallas la contraseña solo vuelve a pedir la contraseña y utiliza
una logica mas adecuada, solo utiliza un bucle, pero requiere el uso de variables de validacion.'''

usuario_valido = False
contraseña_valida = False

while not (usuario_valido and contraseña_valida):
    if not usuario_valido:
        usuario = input("Ingrese su nombre de usuario (minimo 5 caracteres): ")
        if len(usuario) >= 5:
            usuario_valido = True
        else:
            print("Nombre de usuario debe tener al menos 5 caracteres")
            continue # Vuelve al inicio para pedir el nombre de usuario de nuevo

    # Si llegamos aquí, el nombre de usuario es válido, ahora validamos la contraseña
    if not contraseña_valida:
        contraseña = input("Ingrese su contraseña (minimo 8 caracteres): ")
        if len(contraseña) >= 8:
            contraseña_valida = True
        else:
            print("Contraseña debe tener al menos 8 caracteres")
            # No usamos 'continue' aquí si queremos que vuelva a pedir solo la contraseña
            # En este caso, el bucle principal 'while not (usuario_valido and contraseña_valida)'
            # se encargará de seguir pidiendo la contraseña porque contraseña_valida es False

print("¡Registro realizado con éxito!")

# %%
''' Cumple, pero al fallar la contraseña, vuelve a solicitar el nombre, el cual ya estaba validado.'''

#codigo instructor.

while True:
    nombre_usuario = input("Digite su nombre de usuario: ")
    contraseña = input("Digite su contraseña: ")

    if len(nombre_usuario) < 5:
        print("El nombre de usuario debe tener al menos 5 caracteres.")
        continue

    if len(contraseña) < 8:
        print("La contraseña debe tener al menos 8 caracteres.")
        continue

    print("¡Registro realizado con éxito!")
    break
